# %% [markdown]
# # The Open Data Cube and Metadata
#
# The ODC has been purposely built to access and analyse earth observation data and metadata. In this notebook, we will explore basic methods that can be used to extract metadata from DEA products stored on the public s3, which we have indexed into our instance of the ODC.

# %%
# First we will load some Python modules
import datacube
import pandas

# And we set some configuration
# %matplotlib inline
pandas.set_option('display.max_colwidth', 200)
pandas.set_option('display.max_rows', None)

# %% [markdown]
# ## First steps
# Let's explore what products have been indexed into our ODC instance and what associated information there is available within the metadata.

# %%
dc = datacube.Datacube(app='metadata-demo') # Start a datacube instance.

# %%
products = dc.list_products() # Get all available product information
products
# Out:
#                           name  \
# id
# 10               ls5_fc_albers
# 5   ls5_nbart_geomedian_annual
# 11               ls7_fc_albers
# 4   ls7_nbart_geomedian_annual
# 2                ls8_fc_albers
# 3   ls8_nbart_geomedian_annual
# 6              s2a_l1c_aws_pds
# 8              s2a_nrt_granule
# 7              s2b_l1c_aws_pds
# 9              s2b_nrt_granule
# 1                  wofs_albers
#
#                                                                                                        description  \
# id
# 10            Landsat 5 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 5   Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 11            Landsat 7 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 4   Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 2             Landsat 8 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 3   Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 6                                                                                    Sentinel-2A MSI L1C - AWS PDS
# 8                                                               Sentinel-2A MSI NRT - NBAR NBART and Pixel Quality
# 7                                                                                    Sentinel-2B MSI L1C - AWS PDS
# 9                                                               Sentinel-2B MSI NRT - NBAR NBART and Pixel Quality
# 1                                                             Historic Flood Mapping Water Observations from Space
#
#    creation_time                             product_type   lon   lat  \
# id
# 10          None                         fractional_cover  None  None
# 5           None  surface_reflectance_statistical_summary  None  None
# 11          None                         fractional_cover  None  None
# 4           None  surface_reflectance_statistical_summary  None  None
# 2           None                         fractional_cover  None  None
# 3           None  surface_reflectance_statistical_summary  None  None
# 6           None                                   level1  None  None
# 8           None                                      ard  None  None
# 7           None                                   level1  None  None
# 9           None                                      ard  None  None
# 1           None                                     wofs  None  None
#
#                          platform       instrument label  time    format  \
# id
# 10                      LANDSAT_5               TM  None  None      None
# 5                       LANDSAT_5               TM  None  None   GeoTIFF
# 11                      LANDSAT_7              ETM  None  None      None
# 4                       LANDSAT_7              ETM  None  None   GeoTIFF
# 2                       LANDSAT_8         OLI_TIRS  None  None   GeoTIFF
# 3                       LANDSAT_8              OLI  None  None   GeoTIFF
# 6                     SENTINEL_2A              MSI  None  None  JPEG2000
# 8                     SENTINEL_2A              MSI  None  None   GeoTiff
# 7                     SENTINEL_2B              MSI  None  None  JPEG2000
# 9                     SENTINEL_2B              MSI  None  None   GeoTiff
# 1   LANDSAT_5,LANDSAT_7,LANDSAT_8  TM,ETM,OLI_TIRS  None  None   GeoTIFF
#
#           crs resolution             tile_size spatial_dimensions
# id
# 10  EPSG:3577  [-25, 25]  [100000.0, 100000.0]             (y, x)
# 5   EPSG:3577  [-25, 25]  [100000.0, 100000.0]             (y, x)
# 11  EPSG:3577  [-25, 25]  [100000.0, 100000.0]             (y, x)
# 4   EPSG:3577  [-25, 25]  [100000.0, 100000.0]             (y, x)
# 2   EPSG:3577  [-25, 25]                  None             (y, x)
# 3   EPSG:3577  [-25, 25]  [100000.0, 100000.0]             (y, x)
# 6         NaN        NaN                   NaN                NaN
# 8         NaN        NaN                   NaN                NaN
# 7         NaN        NaN                   NaN                NaN
# 9         NaN        NaN                   NaN                NaN
# 1         NaN        NaN                   NaN                NaN

# %%
# Here we search products for those that match the string 'SENT', i.e., Sentinel
products[products['platform'].str.match('SENT')]
# Out:
#                name                                         description  \
# id
# 6   s2a_l1c_aws_pds                       Sentinel-2A MSI L1C - AWS PDS
# 8   s2a_nrt_granule  Sentinel-2A MSI NRT - NBAR NBART and Pixel Quality
# 7   s2b_l1c_aws_pds                       Sentinel-2B MSI L1C - AWS PDS
# 9   s2b_nrt_granule  Sentinel-2B MSI NRT - NBAR NBART and Pixel Quality
#
#    creation_time product_type   lon   lat     platform instrument label  time  \
# id
# 6           None       level1  None  None  SENTINEL_2A        MSI  None  None
# 8           None          ard  None  None  SENTINEL_2A        MSI  None  None
# 7           None       level1  None  None  SENTINEL_2B        MSI  None  None
# 9           None          ard  None  None  SENTINEL_2B        MSI  None  None
#
#       format  crs resolution tile_size spatial_dimensions
# id
# 6   JPEG2000  NaN        NaN       NaN                NaN
# 8    GeoTiff  NaN        NaN       NaN                NaN
# 7   JPEG2000  NaN        NaN       NaN                NaN
# 9    GeoTiff  NaN        NaN       NaN                NaN

# %%
# Measurements are variables that are available for a product
measurements = dc.list_measurements() # Get all measurement information
measurements
# Out:
#                                                                                    aliases  \
# product                    measurement
# ls5_fc_albers              BS                                                       [bare]
#                            PV                                                  [green_veg]
#                            NPV                                                  [dead_veg]
#                            UE                                                        [err]
# ls5_nbart_geomedian_annual blue                                                        NaN
#                            green                                                       NaN
#                            red                                                         NaN
#                            nir                                                         NaN
#                            swir1                                                       NaN
#                            swir2                                                       NaN
# ls7_fc_albers              BS                                                       [bare]
#                            PV                                                  [green_veg]
#                            NPV                                                  [dead_veg]
#                            UE                                                        [err]
# ls7_nbart_geomedian_annual blue                                                        NaN
#                            green                                                       NaN
#                            red                                                         NaN
#                            nir                                                         NaN
#                            swir1                                                       NaN
#                            swir2                                                       NaN
# ls8_fc_albers              BS                                                       [bare]
#                            PV                                                  [green_veg]
#                            NPV                                                  [dead_veg]
#                            UE                                                        [err]
# ls8_nbart_geomedian_annual blue                                                        NaN
#                            green                                                       NaN
#                            red                                                         NaN
#                            nir                                                         NaN
#                            swir1                                                       NaN
#                            swir2                                                       NaN
# s2a_nrt_granule            azimuthal_exiting                           [azimuthal_exiting]
#                            azimuthal_incident                         [azimuthal_incident]
#                            exiting                                               [exiting]
#                            incident                                             [incident]
#                            relative_azimuth                             [relative_azimuth]
#                            relative_slope                                 [relative_slope]
#                            satellite_azimuth                           [satellite_azimuth]
#                            satellite_view                                 [satellite_view]
#                            solar_azimuth                                   [solar_azimuth]
#                            solar_zenith                                     [solar_zenith]
#                            terrain_shadow                                 [terrain_shadow]
#                            fmask                                             [mask, Fmask]
#                            nbar_contiguity                                             NaN
#                            nbar_coastal_aerosol       [nbar_band_01, nbar_B01, nbar_Band1]
#                            nbar_blue                  [nbar_band_02, nbar_B02, nbar_Band2]
#                            nbar_green                 [nbar_band_03, nbar_B03, nbar_Band3]
#                            nbar_red                   [nbar_band_04, nbar_B04, nbar_Band4]
#                            nbar_red_edge_1            [nbar_band_05, nbar_B05, nbar_Band5]
#                            nbar_red_edge_2            [nbar_band_06, nbar_B06, nbar_Band6]
#                            nbar_red_edge_3            [nbar_band_07, nbar_B07, nbar_Band7]
#                            nbar_nir_1                 [nbar_band_08, nbar_B08, nbar_Band8]
#                            nbar_nir_2                [nbar_band_8A, nbar_B8A, nbar_Band8A]
#                            nbar_swir_2               [nbar_band_11, nbar_B11, nbar_Band11]
#                            nbar_swir_3               [nbar_band_12, nbar_B12, nbar_Band12]
#                            nbart_contiguity                                            NaN
#                            nbart_coastal_aerosol   [nbart_band_01, nbart_B01, nbart_Band1]
#                            nbart_blue              [nbart_band_02, nbart_B02, nbart_Band2]
#                            nbart_green             [nbart_band_03, nbart_B03, nbart_Band3]
#                            nbart_red               [nbart_band_04, nbart_B04, nbart_Band4]
#                            nbart_red_edge_1        [nbart_band_05, nbart_B05, nbart_Band5]
#                            nbart_red_edge_2        [nbart_band_06, nbart_B06, nbart_Band6]
#                            nbart_red_edge_3        [nbart_band_07, nbart_B07, nbart_Band7]
#                            nbart_nir_1             [nbart_band_08, nbart_B08, nbart_Band8]
#                            nbart_nir_2            [nbart_band_8A, nbart_B8A, nbart_Band8A]
#                            nbart_swir_2           [nbart_band_11, nbart_B11, nbart_Band11]
#                            nbart_swir_3           [nbart_band_12, nbart_B12, nbart_Band12]
# s2b_nrt_granule            azimuthal_exiting                           [azimuthal_exiting]
#                            azimuthal_incident                         [azimuthal_incident]
#                            exiting                                               [exiting]
#                            incident                                             [incident]
#                            relative_azimuth                             [relative_azimuth]
#                            relative_slope                                 [relative_slope]
#                            satellite_azimuth                           [satellite_azimuth]
#                            satellite_view                                 [satellite_view]
#                            solar_azimuth                                   [solar_azimuth]
#                            solar_zenith                                     [solar_zenith]
#                            terrain_shadow                                 [terrain_shadow]
#                            fmask                                             [mask, Fmask]
#                            nbar_contiguity                                             NaN
#                            nbar_coastal_aerosol       [nbar_band_01, nbar_B01, nbar_Band1]
#                            nbar_blue                  [nbar_band_02, nbar_B02, nbar_Band2]
#                            nbar_green                 [nbar_band_03, nbar_B03, nbar_Band3]
#                            nbar_red                   [nbar_band_04, nbar_B04, nbar_Band4]
#                            nbar_red_edge_1            [nbar_band_05, nbar_B05, nbar_Band5]
#                            nbar_red_edge_2            [nbar_band_06, nbar_B06, nbar_Band6]
#                            nbar_red_edge_3            [nbar_band_07, nbar_B07, nbar_Band7]
#                            nbar_nir_1                 [nbar_band_08, nbar_B08, nbar_Band8]
#                            nbar_nir_2                [nbar_band_8A, nbar_B8A, nbar_Band8A]
#                            nbar_swir_2               [nbar_band_11, nbar_B11, nbar_Band11]
#                            nbar_swir_3               [nbar_band_12, nbar_B12, nbar_Band12]
#                            nbart_contiguity                                            NaN
#                            nbart_coastal_aerosol   [nbart_band_01, nbart_B01, nbart_Band1]
#                            nbart_blue              [nbart_band_02, nbart_B02, nbart_Band2]
#                            nbart_green             [nbart_band_03, nbart_B03, nbart_Band3]
#                            nbart_red               [nbart_band_04, nbart_B04, nbart_Band4]
#                            nbart_red_edge_1        [nbart_band_05, nbart_B05, nbart_Band5]
#                            nbart_red_edge_2        [nbart_band_06, nbart_B06, nbart_Band6]
#                            nbart_red_edge_3        [nbart_band_07, nbart_B07, nbart_Band7]
#                            nbart_nir_1             [nbart_band_08, nbart_B08, nbart_Band8]
#                            nbart_nir_2            [nbart_band_8A, nbart_B8A, nbart_Band8A]
#                            nbart_swir_2           [nbart_band_11, nbart_B11, nbart_Band11]
#                            nbart_swir_3           [nbart_band_12, nbart_B12, nbart_Band12]
# wofs_albers                water                                                       NaN
#
#                                                     dtype  \
# product                    measurement
# ls5_fc_albers              BS                        int8
#                            PV                        int8
#                            NPV                       int8
#                            UE                        int8
# ls5_nbart_geomedian_annual blue                     int16
#                            green                    int16
#                            red                      int16
#                            nir                      int16
#                            swir1                    int16
#                            swir2                    int16
# ls7_fc_albers              BS                        int8
#                            PV                        int8
#                            NPV                       int8
#                            UE                        int8
# ls7_nbart_geomedian_annual blue                     int16
#                            green                    int16
#                            red                      int16
#                            nir                      int16
#                            swir1                    int16
#                            swir2                    int16
# ls8_fc_albers              BS                       uint8
#                            PV                       uint8
#                            NPV                      uint8
#                            UE                       uint8
# ls8_nbart_geomedian_annual blue                     int16
#                            green                    int16
#                            red                      int16
#                            nir                      int16
#                            swir1                    int16
#                            swir2                    int16
# s2a_nrt_granule            azimuthal_exiting      float32
#                            azimuthal_incident     float32
#                            exiting                float32
#                            incident               float32
#                            relative_azimuth       float32
#                            relative_slope         float32
#                            satellite_azimuth      float32
#                            satellite_view         float32
#                            solar_azimuth          float32
#                            solar_zenith           float32
#                            terrain_shadow           uint8
#                            fmask                    uint8
#                            nbar_contiguity          uint8
#                            nbar_coastal_aerosol     int16
#                            nbar_blue                int16
#                            nbar_green               int16
#                            nbar_red                 int16
#                            nbar_red_edge_1          int16
#                            nbar_red_edge_2          int16
#                            nbar_red_edge_3          int16
#                            nbar_nir_1               int16
#                            nbar_nir_2               int16
#                            nbar_swir_2              int16
#                            nbar_swir_3              int16
#                            nbart_contiguity         uint8
#                            nbart_coastal_aerosol    int16
#                            nbart_blue               int16
#                            nbart_green              int16
#                            nbart_red                int16
#                            nbart_red_edge_1         int16
#                            nbart_red_edge_2         int16
#                            nbart_red_edge_3         int16
#                            nbart_nir_1              int16
#                            nbart_nir_2              int16
#                            nbart_swir_2             int16
#                            nbart_swir_3             int16
# s2b_nrt_granule            azimuthal_exiting      float32
#                            azimuthal_incident     float32
#                            exiting                float32
#                            incident               float32
#                            relative_azimuth       float32
#                            relative_slope         float32
#                            satellite_azimuth      float32
#                            satellite_view         float32
#                            solar_azimuth          float32
#                            solar_zenith           float32
#                            terrain_shadow           uint8
#                            fmask                    uint8
#                            nbar_contiguity          uint8
#                            nbar_coastal_aerosol     int16
#                            nbar_blue                int16
#                            nbar_green               int16
#                            nbar_red                 int16
#                            nbar_red_edge_1          int16
#                            nbar_red_edge_2          int16
#                            nbar_red_edge_3          int16
#                            nbar_nir_1               int16
#                            nbar_nir_2               int16
#                            nbar_swir_2              int16
#                            nbar_swir_3              int16
#                            nbart_contiguity         uint8
#                            nbart_coastal_aerosol    int16
#                            nbart_blue               int16
#                            nbart_green              int16
#                            nbart_red                int16
#                            nbart_red_edge_1         int16
#                            nbart_red_edge_2         int16
#                            nbart_red_edge_3         int16
#                            nbart_nir_1              int16
#                            nbart_nir_2              int16
#                            nbart_swir_2             int16
#                            nbart_swir_3             int16
# wofs_albers                water                    int16
#
#                                                                                                                                                                                                                                          flags_definition  \
# product                    measurement
# ls5_fc_albers              BS                                                                                                                                                                                                                         NaN
#                            PV                                                                                                                                                                                                                         NaN
#                            NPV                                                                                                                                                                                                                        NaN
#                            UE                                                                                                                                                                                                                         NaN
# ls5_nbart_geomedian_annual blue                                                                                                                                                                                                                       NaN
#                            green                                                                                                                                                                                                                      NaN
#                            red                                                                                                                                                                                                                        NaN
#                            nir                                                                                                                                                                                                                        NaN
#                            swir1                                                                                                                                                                                                                      NaN
#                            swir2                                                                                                                                                                                                                      NaN
# ls7_fc_albers              BS                                                                                                                                                                                                                         NaN
#                            PV                                                                                                                                                                                                                         NaN
#                            NPV                                                                                                                                                                                                                        NaN
#                            UE                                                                                                                                                                                                                         NaN
# ls7_nbart_geomedian_annual blue                                                                                                                                                                                                                       NaN
#                            green                                                                                                                                                                                                                      NaN
#                            red                                                                                                                                                                                                                        NaN
#                            nir                                                                                                                                                                                                                        NaN
#                            swir1                                                                                                                                                                                                                      NaN
#                            swir2                                                                                                                                                                                                                      NaN
# ls8_fc_albers              BS                                                                                                                                                                                                                         NaN
#                            PV                                                                                                                                                                                                                         NaN
#                            NPV                                                                                                                                                                                                                        NaN
#                            UE                                                                                                                                                                                                                         NaN
# ls8_nbart_geomedian_annual blue                                                                                                                                                                                                                       NaN
#                            green                                                                                                                                                                                                                      NaN
#                            red                                                                                                                                                                                                                        NaN
#                            nir                                                                                                                                                                                                                        NaN
#                            swir1                                                                                                                                                                                                                      NaN
#                            swir2                                                                                                                                                                                                                      NaN
# s2a_nrt_granule            azimuthal_exiting                                                                                                                                                                                                          NaN
#                            azimuthal_incident                                                                                                                                                                                                         NaN
#                            exiting                                                                                                                                                                                                                    NaN
#                            incident                                                                                                                                                                                                                   NaN
#                            relative_azimuth                                                                                                                                                                                                           NaN
#                            relative_slope                                                                                                                                                                                                             NaN
#                            satellite_azimuth                                                                                                                                                                                                          NaN
#                            satellite_view                                                                                                                                                                                                             NaN
#                            solar_azimuth                                                                                                                                                                                                              NaN
#                            solar_zenith                                                                                                                                                                                                               NaN
#                            terrain_shadow                                                                                                                                                                                                             NaN
#                            fmask                                                   {'fmask': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'nodata', '1': 'valid', '2': 'cloud', '3': 'shadow', '4': 'snow', '5': 'water'}, 'description': 'Fmask'}}
#                            nbar_contiguity                                                      {'contiguity': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'not_contiguous', '1': 'contiguous'}, 'description': 'Pixel contiguity in band stack'}}
#                            nbar_coastal_aerosol                                                                                                                                                                                                       NaN
#                            nbar_blue                                                                                                                                                                                                                  NaN
#                            nbar_green                                                                                                                                                                                                                 NaN
#                            nbar_red                                                                                                                                                                                                                   NaN
#                            nbar_red_edge_1                                                                                                                                                                                                            NaN
#                            nbar_red_edge_2                                                                                                                                                                                                            NaN
#                            nbar_red_edge_3                                                                                                                                                                                                            NaN
#                            nbar_nir_1                                                                                                                                                                                                                 NaN
#                            nbar_nir_2                                                                                                                                                                                                                 NaN
#                            nbar_swir_2                                                                                                                                                                                                                NaN
#                            nbar_swir_3                                                                                                                                                                                                                NaN
#                            nbart_contiguity                                                     {'contiguity': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'not_contiguous', '1': 'contiguous'}, 'description': 'Pixel contiguity in band stack'}}
#                            nbart_coastal_aerosol                                                                                                                                                                                                      NaN
#                            nbart_blue                                                                                                                                                                                                                 NaN
#                            nbart_green                                                                                                                                                                                                                NaN
#                            nbart_red                                                                                                                                                                                                                  NaN
#                            nbart_red_edge_1                                                                                                                                                                                                           NaN
#                            nbart_red_edge_2                                                                                                                                                                                                           NaN
#                            nbart_red_edge_3                                                                                                                                                                                                           NaN
#                            nbart_nir_1                                                                                                                                                                                                                NaN
#                            nbart_nir_2                                                                                                                                                                                                                NaN
#                            nbart_swir_2                                                                                                                                                                                                               NaN
#                            nbart_swir_3                                                                                                                                                                                                               NaN
# s2b_nrt_granule            azimuthal_exiting                                                                                                                                                                                                          NaN
#                            azimuthal_incident                                                                                                                                                                                                         NaN
#                            exiting                                                                                                                                                                                                                    NaN
#                            incident                                                                                                                                                                                                                   NaN
#                            relative_azimuth                                                                                                                                                                                                           NaN
#                            relative_slope                                                                                                                                                                                                             NaN
#                            satellite_azimuth                                                                                                                                                                                                          NaN
#                            satellite_view                                                                                                                                                                                                             NaN
#                            solar_azimuth                                                                                                                                                                                                              NaN
#                            solar_zenith                                                                                                                                                                                                               NaN
#                            terrain_shadow                                                                                                                                                                                                             NaN
#                            fmask                                                   {'fmask': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'nodata', '1': 'valid', '2': 'cloud', '3': 'shadow', '4': 'snow', '5': 'water'}, 'description': 'Fmask'}}
#                            nbar_contiguity                                                      {'contiguity': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'not_contiguous', '1': 'contiguous'}, 'description': 'Pixel contiguity in band stack'}}
#                            nbar_coastal_aerosol                                                                                                                                                                                                       NaN
#                            nbar_blue                                                                                                                                                                                                                  NaN
#                            nbar_green                                                                                                                                                                                                                 NaN
#                            nbar_red                                                                                                                                                                                                                   NaN
#                            nbar_red_edge_1                                                                                                                                                                                                            NaN
#                            nbar_red_edge_2                                                                                                                                                                                                            NaN
#                            nbar_red_edge_3                                                                                                                                                                                                            NaN
#                            nbar_nir_1                                                                                                                                                                                                                 NaN
#                            nbar_nir_2                                                                                                                                                                                                                 NaN
#                            nbar_swir_2                                                                                                                                                                                                                NaN
#                            nbar_swir_3                                                                                                                                                                                                                NaN
#                            nbart_contiguity                                                     {'contiguity': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'not_contiguous', '1': 'contiguous'}, 'description': 'Pixel contiguity in band stack'}}
#                            nbart_coastal_aerosol                                                                                                                                                                                                      NaN
#                            nbart_blue                                                                                                                                                                                                                 NaN
#                            nbart_green                                                                                                                                                                                                                NaN
#                            nbart_red                                                                                                                                                                                                                  NaN
#                            nbart_red_edge_1                                                                                                                                                                                                           NaN
#                            nbart_red_edge_2                                                                                                                                                                                                           NaN
#                            nbart_red_edge_3                                                                                                                                                                                                           NaN
#                            nbart_nir_1                                                                                                                                                                                                                NaN
#                            nbart_nir_2                                                                                                                                                                                                                NaN
#                            nbart_swir_2                                                                                                                                                                                                               NaN
#                            nbart_swir_3                                                                                                                                                                                                               NaN
# wofs_albers                water                  {'dry': {'bits': [7, 6, 5, 4, 3, 1, 0], 'values': {'0': True}, 'description': 'No water detected'}, 'sea': {'bits': 2, 'values': {'0': False, '1': True}, 'description': 'Sea'}, 'wet': {'bits': [7,...
#
#                                                                    name  \
# product                    measurement
# ls5_fc_albers              BS                                        BS
#                            PV                                        PV
#                            NPV                                      NPV
#                            UE                                        UE
# ls5_nbart_geomedian_annual blue                                    blue
#                            green                                  green
#                            red                                      red
#                            nir                                      nir
#                            swir1                                  swir1
#                            swir2                                  swir2
# ls7_fc_albers              BS                                        BS
#                            PV                                        PV
#                            NPV                                      NPV
#                            UE                                        UE
# ls7_nbart_geomedian_annual blue                                    blue
#                            green                                  green
#                            red                                      red
#                            nir                                      nir
#                            swir1                                  swir1
#                            swir2                                  swir2
# ls8_fc_albers              BS                                        BS
#                            PV                                        PV
#                            NPV                                      NPV
#                            UE                                        UE
# ls8_nbart_geomedian_annual blue                                    blue
#                            green                                  green
#                            red                                      red
#                            nir                                      nir
#                            swir1                                  swir1
#                            swir2                                  swir2
# s2a_nrt_granule            azimuthal_exiting          azimuthal_exiting
#                            azimuthal_incident        azimuthal_incident
#                            exiting                              exiting
#                            incident                            incident
#                            relative_azimuth            relative_azimuth
#                            relative_slope                relative_slope
#                            satellite_azimuth          satellite_azimuth
#                            satellite_view                satellite_view
#                            solar_azimuth                  solar_azimuth
#                            solar_zenith                    solar_zenith
#                            terrain_shadow                terrain_shadow
#                            fmask                                  fmask
#                            nbar_contiguity              nbar_contiguity
#                            nbar_coastal_aerosol    nbar_coastal_aerosol
#                            nbar_blue                          nbar_blue
#                            nbar_green                        nbar_green
#                            nbar_red                            nbar_red
#                            nbar_red_edge_1              nbar_red_edge_1
#                            nbar_red_edge_2              nbar_red_edge_2
#                            nbar_red_edge_3              nbar_red_edge_3
#                            nbar_nir_1                        nbar_nir_1
#                            nbar_nir_2                        nbar_nir_2
#                            nbar_swir_2                      nbar_swir_2
#                            nbar_swir_3                      nbar_swir_3
#                            nbart_contiguity            nbart_contiguity
#                            nbart_coastal_aerosol  nbart_coastal_aerosol
#                            nbart_blue                        nbart_blue
#                            nbart_green                      nbart_green
#                            nbart_red                          nbart_red
#                            nbart_red_edge_1            nbart_red_edge_1
#                            nbart_red_edge_2            nbart_red_edge_2
#                            nbart_red_edge_3            nbart_red_edge_3
#                            nbart_nir_1                      nbart_nir_1
#                            nbart_nir_2                      nbart_nir_2
#                            nbart_swir_2                    nbart_swir_2
#                            nbart_swir_3                    nbart_swir_3
# ...
#                            nbart_swir_3           {'response': [0.000639, 0.001023, 0.002885, 0.003997, 0.006597, 0.00766, 0.008004, 0.00854, 0.0093, 0.010002, 0.010972, 0.012089, 0.013364, 0.015017, 0.017126, 0.01978, 0.023336, 0.027668, 0.03321...
# s2b_nrt_granule            azimuthal_exiting                                                                                                                                                                                                          NaN
#                            azimuthal_incident                                                                                                                                                                                                         NaN
#                            exiting                                                                                                                                                                                                                    NaN
#                            incident                                                                                                                                                                                                                   NaN
#                            relative_azimuth                                                                                                                                                                                                           NaN
#                            relative_slope                                                                                                                                                                                                             NaN
#                            satellite_azimuth                                                                                                                                                                                                          NaN
#                            satellite_view                                                                                                                                                                                                             NaN
#                            solar_azimuth                                                                                                                                                                                                              NaN
#                            solar_zenith                                                                                                                                                                                                               NaN
#                            terrain_shadow                                                                                                                                                                                                             NaN
#                            fmask                                                                                                                                                                                                                      NaN
#                            nbar_contiguity                                                                                                                                                                                                            NaN
#                            nbar_coastal_aerosol   {'response': [0.006797798, 0.01099643, 0.004208363, 0.006568034, 0.005883123, 0.00713011, 0.004333651, 0.006263537, 0.004393687, 0.00253157, 0.000621707, 0.002117729, 0.003175796, 0.005213085, 0.0...
#                            nbar_blue              {'response': [0.001893306, 0.019440751, 0.020059028, 0.014109631, 0.015612858, 0.015448868, 0.017034152, 0.013311359, 0.014462036, 0.009592091, 0.014500694, 0.011159264, 0.013332524, 0.01355731, 0...
#                            nbar_green             {'response': [0.005090312, 0.026897029, 0.12087986, 0.33742273, 0.603624689, 0.810967523, 0.91573833, 0.92605288, 0.92083242, 0.911237119, 0.902005739, 0.897081513, 0.899066029, 0.900672338, 0.902...
#                            nbar_red               {'response': [0.002584, 0.034529, 0.14997, 0.464826, 0.817746, 0.965324, 0.983869, 0.9969, 1.0, 0.995449, 0.991334, 0.977215, 0.936802, 0.873776, 0.814166, 0.776669, 0.764864, 0.775091, 0.801359, ...
#                            nbar_red_edge_1        {'response': [0.010471827, 0.057252544, 0.214724996, 0.547189415, 0.871043978, 0.968446586, 0.99124182, 1, 0.99509331, 0.987602081, 0.979408704, 0.970910946, 0.959528083, 0.94236861, 0.926720132, ...
#                            nbar_red_edge_2        {'response': [0.017433807, 0.105812957, 0.386050533, 0.782313159, 0.905953099, 0.916416606, 0.92333441, 0.932013378, 0.947550036, 0.965839591, 0.978552758, 0.991319723, 1, 0.999955845, 0.971267313...
#                            nbar_red_edge_3        {'response': [0.010282026, 0.037427714, 0.112026989, 0.257953812, 0.478980823, 0.730216783, 0.912510408, 0.971721033, 0.964616097, 0.955734525, 0.964925586, 0.986223289, 1, 0.998046627, 0.98393444...
#                            nbar_nir_1             {'response': [0.000386696, 0.003018401, 0.01669158, 0.028340486, 0.0502885, 0.08626388, 0.149596686, 0.258428566, 0.425108406, 0.631697563, 0.803109115, 0.904984654, 0.939674653, 0.944958731, 0.94...
#                            nbar_nir_2             {'response': [0.001661751, 0.01602581, 0.032253895, 0.073411273, 0.168937582, 0.345506138, 0.569417239, 0.79634996, 0.937581155, 0.980942645, 0.987241334, 0.994409463, 0.998963959, 0.999788107, 1,...
#                            nbar_swir_2            {'response': [1.15e-05, 2.6996e-05, 8.1157e-05, 0.000169507, 0.000273428, 0.000343776, 0.000459515, 0.000651677, 0.0008223, 0.001076746, 0.001428776, 0.001958681, 0.002660821, 0.003682001, 0.00521...
#                            nbar_swir_3            {'response': [0.000227567, 0.000739283, 0.001656775, 0.003019587, 0.004589377, 0.005924935, 0.007534774, 0.008748008, 0.010265481, 0.012236179, 0.014593479, 0.017458937, 0.021063245, 0.025428056, ...
#                            nbart_contiguity                                                                                                                                                                                                           NaN
#                            nbart_coastal_aerosol  {'response': [0.006797798, 0.01099643, 0.004208363, 0.006568034, 0.005883123, 0.00713011, 0.004333651, 0.006263537, 0.004393687, 0.00253157, 0.000621707, 0.002117729, 0.003175796, 0.005213085, 0.0...
#                            nbart_blue             {'response': [0.001893306, 0.019440751, 0.020059028, 0.014109631, 0.015612858, 0.015448868, 0.017034152, 0.013311359, 0.014462036, 0.009592091, 0.014500694, 0.011159264, 0.013332524, 0.01355731, 0...
#                            nbart_green            {'response': [0.005090312, 0.026897029, 0.12087986, 0.33742273, 0.603624689, 0.810967523, 0.91573833, 0.92605288, 0.92083242, 0.911237119, 0.902005739, 0.897081513, 0.899066029, 0.900672338, 0.902...
#                            nbart_red              {'response': [0.002584, 0.034529, 0.14997, 0.464826, 0.817746, 0.965324, 0.983869, 0.9969, 1.0, 0.995449, 0.991334, 0.977215, 0.936802, 0.873776, 0.814166, 0.776669, 0.764864, 0.775091, 0.801359, ...
#                            nbart_red_edge_1       {'response': [0.010471827, 0.057252544, 0.214724996, 0.547189415, 0.871043978, 0.968446586, 0.99124182, 1, 0.99509331, 0.987602081, 0.979408704, 0.970910946, 0.959528083, 0.94236861, 0.926720132, ...
#                            nbart_red_edge_2       {'response': [0.017433807, 0.105812957, 0.386050533, 0.782313159, 0.905953099, 0.916416606, 0.92333441, 0.932013378, 0.947550036, 0.965839591, 0.978552758, 0.991319723, 1, 0.999955845, 0.971267313...
#                            nbart_red_edge_3       {'response': [0.010282026, 0.037427714, 0.112026989, 0.257953812, 0.478980823, 0.730216783, 0.912510408, 0.971721033, 0.964616097, 0.955734525, 0.964925586, 0.986223289, 1, 0.998046627, 0.98393444...
#                            nbart_nir_1            {'response': [0.000386696, 0.003018401, 0.01669158, 0.028340486, 0.0502885, 0.08626388, 0.149596686, 0.258428566, 0.425108406, 0.631697563, 0.803109115, 0.904984654, 0.939674653, 0.944958731, 0.94...
#                            nbart_nir_2            {'response': [0.001661751, 0.01602581, 0.032253895, 0.073411273, 0.168937582, 0.345506138, 0.569417239, 0.79634996, 0.937581155, 0.980942645, 0.987241334, 0.994409463, 0.998963959, 0.999788107, 1,...
#                            nbart_swir_2           {'response': [1.15e-05, 2.6996e-05, 8.1157e-05, 0.000169507, 0.000273428, 0.000343776, 0.000459515, 0.000651677, 0.0008223, 0.001076746, 0.001428776, 0.001958681, 0.002660821, 0.003682001, 0.00521...
#                            nbart_swir_3           {'response': [0.000227567, 0.000739283, 0.001656775, 0.003019587, 0.004589377, 0.005924935, 0.007534774, 0.008748008, 0.010265481, 0.012236179, 0.014593479, 0.017458937, 0.021063245, 0.025428056, ...
# wofs_albers                water                                                                                                                                                                                                                      NaN
#
#                                                     units
# product                    measurement
# ls5_fc_albers              BS                     percent
#                            PV                     percent
#                            NPV                    percent
#                            UE                           1
# ls5_nbart_geomedian_annual blue                         1
#                            green                        1
#                            red                          1
#                            nir                          1
#                            swir1                        1
#                            swir2                        1
# ls7_fc_albers              BS                     percent
#                            PV                     percent
#                            NPV                    percent
#                            UE                           1
# ls7_nbart_geomedian_annual blue                         1
#                            green                        1
#                            red                          1
#                            nir                          1
#                            swir1                        1
#                            swir2                        1
# ls8_fc_albers              BS                     percent
#                            PV                     percent
#                            NPV                    percent
#                            UE                           1
# ls8_nbart_geomedian_annual blue                         1
#                            green                        1
#                            red                          1
#                            nir                          1
#                            swir1                        1
#                            swir2                        1
# s2a_nrt_granule            azimuthal_exiting            1
#                            azimuthal_incident           1
#                            exiting                      1
#                            incident                     1
#                            relative_azimuth             1
#                            relative_slope               1
#                            satellite_azimuth            1
#                            satellite_view               1
#                            solar_azimuth                1
#                            solar_zenith                 1
#                            terrain_shadow               1
#                            fmask                        1
#                            nbar_contiguity              1
#                            nbar_coastal_aerosol         1
#                            nbar_blue                    1
#                            nbar_green                   1
#                            nbar_red                     1
#                            nbar_red_edge_1              1
#                            nbar_red_edge_2              1
#                            nbar_red_edge_3              1
#                            nbar_nir_1                   1
#                            nbar_nir_2                   1
#                            nbar_swir_2                  1
#                            nbar_swir_3                  1
#                            nbart_contiguity             1
#                            nbart_coastal_aerosol        1
#                            nbart_blue                   1
#                            nbart_green                  1
#                            nbart_red                    1
#                            nbart_red_edge_1             1
#                            nbart_red_edge_2             1
#                            nbart_red_edge_3             1
#                            nbart_nir_1                  1
#                            nbart_nir_2                  1
#                            nbart_swir_2                 1
#                            nbart_swir_3                 1
# s2b_nrt_granule            azimuthal_exiting            1
#                            azimuthal_incident           1
#                            exiting                      1
#                            incident                     1
#                            relative_azimuth             1
#                            relative_slope               1
#                            satellite_azimuth            1
#                            satellite_view               1
#                            solar_azimuth                1
#                            solar_zenith                 1
#                            terrain_shadow               1
#                            fmask                        1
#                            nbar_contiguity              1
#                            nbar_coastal_aerosol         1
#                            nbar_blue                    1
#                            nbar_green                   1
#                            nbar_red                     1
#                            nbar_red_edge_1              1
#                            nbar_red_edge_2              1
#                            nbar_red_edge_3              1
#                            nbar_nir_1                   1
#                            nbar_nir_2                   1
#                            nbar_swir_2                  1
#                            nbar_swir_3                  1
#                            nbart_contiguity             1
#                            nbart_coastal_aerosol        1
#                            nbart_blue                   1
#                            nbart_green                  1
#                            nbart_red                    1
#                            nbart_red_edge_1             1
#                            nbart_red_edge_2             1
#                            nbart_red_edge_3             1
#                            nbart_nir_1                  1
#                            nbart_nir_2                  1
#                            nbart_swir_2                 1
#                            nbart_swir_3                 1
# wofs_albers                water                        1

# %% [markdown]
# ## Querying Metadata for an Individual Dataset
#
# This is an example of a basic query. More advanced queries can be done to filter based on product lineage, among other things.

# %%
dc = datacube.Datacube(app='advance-query-example')
scenes = dc.find_datasets(
    product='s2a_nrt_granule', 
    time=('2018-09-01', ('2018-10-01')),
    x=(146.30, 146.40), y=(-43.30,-43.20)
)
scenes

# %%
for scene in scenes:
    uid =  scene.id
    bounds = scene.bounds
    time = scene.center_time

    print("uid: {},\t date: {},\t bounds: {}".format(
        uid,
        time.date(),
        [bounds.left, bounds.bottom, bounds.right, bounds.top]
    ))
# Out:
# uid: 8ae129db-3457-41a4-8126-f4d5ad411aab,	 date: 2018-09-17,	 bounds: [399960, 5190220, 509760, 5300020]
# uid: 9be02a41-93ea-43e2-a1f9-ff062be46a3e,	 date: 2018-09-30,	 bounds: [399960, 5190220, 509760, 5300020]
# uid: 52b10515-a1d3-43e4-b07f-1a4984bc4e47,	 date: 2018-09-10,	 bounds: [399960, 5190220, 509760, 5300020]
# uid: c1cd1733-f02f-4cff-a54d-376fb3844bfc,	 date: 2018-09-27,	 bounds: [399960, 5190220, 509760, 5300020]
# uid: 9af91f68-6977-43f8-9d04-cd265ac54a81,	 date: 2018-09-07,	 bounds: [399960, 5190220, 509760, 5300020]

# %%
dir(scenes[0].metadata)
# Out:
# ['creation_time',
#  'format',
#  'grid_spatial',
#  'id',
#  'instrument',
#  'label',
#  'lat',
#  'lon',
#  'measurements',
#  'platform',
#  'product_type',
#  'sources',
#  'time']

# %%
for scene in scenes:
    print ('location of metadata:\n')
    print (scene.id)
    print (scene.uris)
    print ('---------------------\n')
    
    for measurement in scene.measurements:
        print("insturement: {},\t path: {}".format(measurement, scenes[0].measurements[measurement]['path']))
# Out:
# location of meta-data
# 8ae129db-3457-41a4-8126-f4d5ad411aab
# ['s3://dea-public-data/L2/sentinel-2-nrt/S2MSIARD/2018-09-17/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06/ARD-METADATA.yaml']
# ---------------------
# insturement: fmask,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_FMASK.TIF
# insturement: exiting,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_EXITING.TIF
# insturement: incident,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_INCIDENT.TIF
# insturement: nbar_red,	 path: NBAR/NBAR_B04.TIF
# insturement: nbar_blue,	 path: NBAR/NBAR_B02.TIF
# insturement: nbart_red,	 path: NBART/NBART_B04.TIF
# insturement: timedelta,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_TIMEDELTA.TIF
# insturement: nbar_green,	 path: NBAR/NBAR_B03.TIF
# insturement: nbar_nir_1,	 path: NBAR/NBAR_B08.TIF
# insturement: nbar_nir_2,	 path: NBAR/NBAR_B8A.TIF
# insturement: nbart_blue,	 path: NBART/NBART_B02.TIF
# insturement: nbar_swir_2,	 path: NBAR/NBAR_B11.TIF
# insturement: nbar_swir_3,	 path: NBAR/NBAR_B12.TIF
# insturement: nbart_green,	 path: NBART/NBART_B03.TIF
# insturement: nbart_nir_1,	 path: NBART/NBART_B08.TIF
# insturement: nbart_nir_2,	 path: NBART/NBART_B8A.TIF
# insturement: nbart_swir_2,	 path: NBART/NBART_B11.TIF
# insturement: nbart_swir_3,	 path: NBART/NBART_B12.TIF
# insturement: solar_zenith,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SOLAR_ZENITH.TIF
# insturement: solar_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SOLAR_AZIMUTH.TIF
# insturement: lambertian_red,	 path: LAMBERTIAN/LAMBERTIAN_B04.TIF
# insturement: relative_slope,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_RELATIVE_SLOPE.TIF
# insturement: satellite_view,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SATELLITE_VIEW.TIF
# insturement: terrain_shadow,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_COMBINED_TERRAIN_SHADOW.TIF
# insturement: lambertian_blue,	 path: LAMBERTIAN/LAMBERTIAN_B02.TIF
# insturement: nbar_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_NBAR_CONTIGUITY.TIF
# insturement: nbar_red_edge_1,	 path: NBAR/NBAR_B05.TIF
# insturement: nbar_red_edge_2,	 path: NBAR/NBAR_B06.TIF
# insturement: nbar_red_edge_3,	 path: NBAR/NBAR_B07.TIF
# insturement: lambertian_green,	 path: LAMBERTIAN/LAMBERTIAN_B03.TIF
# insturement: lambertian_nir_1,	 path: LAMBERTIAN/LAMBERTIAN_B08.TIF
# insturement: lambertian_nir_2,	 path: LAMBERTIAN/LAMBERTIAN_B8A.TIF
# insturement: nbart_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_NBART_CONTIGUITY.TIF
# insturement: nbart_red_edge_1,	 path: NBART/NBART_B05.TIF
# insturement: nbart_red_edge_2,	 path: NBART/NBART_B06.TIF
# insturement: nbart_red_edge_3,	 path: NBART/NBART_B07.TIF
# insturement: relative_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_RELATIVE_AZIMUTH.TIF
# insturement: azimuthal_exiting,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_AZIMUTHAL_EXITING.TIF
# insturement: lambertian_swir_2,	 path: LAMBERTIAN/LAMBERTIAN_B11.TIF
# insturement: lambertian_swir_3,	 path: LAMBERTIAN/LAMBERTIAN_B12.TIF
# insturement: satellite_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SATELLITE_AZIMUTH.TIF
# insturement: azimuthal_incident,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_AZIMUTHAL_INCIDENT.TIF
# insturement: nbar_coastal_aerosol,	 path: NBAR/NBAR_B01.TIF
# insturement: lambertian_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_LAMBERTIAN_CONTIGUITY.TIF
# insturement: lambertian_red_edge_1,	 path: LAMBERTIAN/LAMBERTIAN_B05.TIF
# insturement: lambertian_red_edge_2,	 path: LAMBERTIAN/LAMBERTIAN_B06.TIF
# insturement: lambertian_red_edge_3,	 path: LAMBERTIAN/LAMBERTIAN_B07.TIF
# insturement: nbart_coastal_aerosol,	 path: NBART/NBART_B01.TIF
# insturement: lambertian_coastal_aerosol,	 path: LAMBERTIAN/LAMBERTIAN_B01.TIF
# location of meta-data
# 9be02a41-93ea-43e2-a1f9-ff062be46a3e
# ['s3://dea-public-data/L2/sentinel-2-nrt/S2MSIARD/2018-09-30/S2A_OPER_MSI_ARD_TL_EPAE_20180930T013326_A017087_T55GDN_N02.06/ARD-METADATA.yaml']
# ---------------------
# insturement: fmask,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_FMASK.TIF
# insturement: exiting,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_EXITING.TIF
# insturement: incident,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_INCIDENT.TIF
# insturement: nbar_red,	 path: NBAR/NBAR_B04.TIF
# insturement: nbar_blue,	 path: NBAR/NBAR_B02.TIF
# insturement: nbart_red,	 path: NBART/NBART_B04.TIF
# insturement: timedelta,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_TIMEDELTA.TIF
# insturement: nbar_green,	 path: NBAR/NBAR_B03.TIF
# insturement: nbar_nir_1,	 path: NBAR/NBAR_B08.TIF
# insturement: nbar_nir_2,	 path: NBAR/NBAR_B8A.TIF
# insturement: nbart_blue,	 path: NBART/NBART_B02.TIF
# insturement: nbar_swir_2,	 path: NBAR/NBAR_B11.TIF
# insturement: nbar_swir_3,	 path: NBAR/NBAR_B12.TIF
# insturement: nbart_green,	 path: NBART/NBART_B03.TIF
# insturement: nbart_nir_1,	 path: NBART/NBART_B08.TIF
# insturement: nbart_nir_2,	 path: NBART/NBART_B8A.TIF
# insturement: nbart_swir_2,	 path: NBART/NBART_B11.TIF
# insturement: nbart_swir_3,	 path: NBART/NBART_B12.TIF
# insturement: solar_zenith,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SOLAR_ZENITH.TIF
# insturement: solar_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SOLAR_AZIMUTH.TIF
# insturement: lambertian_red,	 path: LAMBERTIAN/LAMBERTIAN_B04.TIF
# insturement: relative_slope,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_RELATIVE_SLOPE.TIF
# insturement: satellite_view,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SATELLITE_VIEW.TIF
# insturement: terrain_shadow,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_COMBINED_TERRAIN_SHADOW.TIF
# insturement: lambertian_blue,	 path: LAMBERTIAN/LAMBERTIAN_B02.TIF
# insturement: nbar_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_NBAR_CONTIGUITY.TIF
# insturement: nbar_red_edge_1,	 path: NBAR/NBAR_B05.TIF
# insturement: nbar_red_edge_2,	 path: NBAR/NBAR_B06.TIF
# insturement: nbar_red_edge_3,	 path: NBAR/NBAR_B07.TIF
# insturement: lambertian_green,	 path: LAMBERTIAN/LAMBERTIAN_B03.TIF
# insturement: lambertian_nir_1,	 path: LAMBERTIAN/LAMBERTIAN_B08.TIF
# insturement: lambertian_nir_2,	 path: LAMBERTIAN/LAMBERTIAN_B8A.TIF
# insturement: nbart_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_NBART_CONTIGUITY.TIF
# insturement: nbart_red_edge_1,	 path: NBART/NBART_B05.TIF
# insturement: nbart_red_edge_2,	 path: NBART/NBART_B06.TIF
# insturement: nbart_red_edge_3,	 path: NBART/NBART_B07.TIF
# insturement: relative_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_RELATIVE_AZIMUTH.TIF
# insturement: azimuthal_exiting,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_AZIMUTHAL_EXITING.TIF
# insturement: lambertian_swir_2,	 path: LAMBERTIAN/LAMBERTIAN_B11.TIF
# insturement: lambertian_swir_3,	 path: LAMBERTIAN/LAMBERTIAN_B12.TIF
# insturement: satellite_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SATELLITE_AZIMUTH.TIF
# insturement: azimuthal_incident,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_AZIMUTHAL_INCIDENT.TIF
# insturement: nbar_coastal_aerosol,	 path: NBAR/NBAR_B01.TIF
# insturement: lambertian_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_LAMBERTIAN_CONTIGUITY.TIF
# insturement: lambertian_red_edge_1,	 path: LAMBERTIAN/LAMBERTIAN_B05.TIF
# insturement: lambertian_red_edge_2,	 path: LAMBERTIAN/LAMBERTIAN_B06.TIF
# insturement: lambertian_red_edge_3,	 path: LAMBERTIAN/LAMBERTIAN_B07.TIF
# insturement: nbart_coastal_aerosol,	 path: NBART/NBART_B01.TIF
# insturement: lambertian_coastal_aerosol,	 path: LAMBERTIAN/LAMBERTIAN_B01.TIF
# location of meta-data
# 52b10515-a1d3-43e4-b07f-1a4984bc4e47
# ['s3://dea-public-data/L2/sentinel-2-nrt/S2MSIARD/2018-09-10/S2A_OPER_MSI_ARD_TL_EPAE_20180910T031916_A016801_T55GDN_N02.06/ARD-METADATA.yaml']
# ---------------------
# insturement: fmask,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_FMASK.TIF
# insturement: exiting,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_EXITING.TIF
# insturement: incident,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_INCIDENT.TIF
# insturement: nbar_red,	 path: NBAR/NBAR_B04.TIF
# insturement: nbar_blue,	 path: NBAR/NBAR_B02.TIF
# insturement: nbart_red,	 path: NBART/NBART_B04.TIF
# insturement: timedelta,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_TIMEDELTA.TIF
# insturement: nbar_green,	 path: NBAR/NBAR_B03.TIF
# insturement: nbar_nir_1,	 path: NBAR/NBAR_B08.TIF
# insturement: nbar_nir_2,	 path: NBAR/NBAR_B8A.TIF
# insturement: nbart_blue,	 path: NBART/NBART_B02.TIF
# insturement: nbar_swir_2,	 path: NBAR/NBAR_B11.TIF
# insturement: nbar_swir_3,	 path: NBAR/NBAR_B12.TIF
# insturement: nbart_green,	 path: NBART/NBART_B03.TIF
# insturement: nbart_nir_1,	 path: NBART/NBART_B08.TIF
# insturement: nbart_nir_2,	 path: NBART/NBART_B8A.TIF
# insturement: nbart_swir_2,	 path: NBART/NBART_B11.TIF
# insturement: nbart_swir_3,	 path: NBART/NBART_B12.TIF
# insturement: solar_zenith,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SOLAR_ZENITH.TIF
# insturement: solar_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SOLAR_AZIMUTH.TIF
# insturement: lambertian_red,	 path: LAMBERTIAN/LAMBERTIAN_B04.TIF
# insturement: relative_slope,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_RELATIVE_SLOPE.TIF
# insturement: satellite_view,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SATELLITE_VIEW.TIF
# insturement: terrain_shadow,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_COMBINED_TERRAIN_SHADOW.TIF
# insturement: lambertian_blue,	 path: LAMBERTIAN/LAMBERTIAN_B02.TIF
# insturement: nbar_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_NBAR_CONTIGUITY.TIF
# insturement: nbar_red_edge_1,	 path: NBAR/NBAR_B05.TIF
# insturement: nbar_red_edge_2,	 path: NBAR/NBAR_B06.TIF
# insturement: nbar_red_edge_3,	 path: NBAR/NBAR_B07.TIF
# insturement: lambertian_green,	 path: LAMBERTIAN/LAMBERTIAN_B03.TIF
# insturement: lambertian_nir_1,	 path: LAMBERTIAN/LAMBERTIAN_B08.TIF
# insturement: lambertian_nir_2,	 path: LAMBERTIAN/LAMBERTIAN_B8A.TIF
# insturement: nbart_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_NBART_CONTIGUITY.TIF
# insturement: nbart_red_edge_1,	 path: NBART/NBART_B05.TIF
# insturement: nbart_red_edge_2,	 path: NBART/NBART_B06.TIF
# insturement: nbart_red_edge_3,	 path: NBART/NBART_B07.TIF
# insturement: relative_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_RELATIVE_AZIMUTH.TIF
# insturement: azimuthal_exiting,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_AZIMUTHAL_EXITING.TIF
# insturement: lambertian_swir_2,	 path: LAMBERTIAN/LAMBERTIAN_B11.TIF
# insturement: lambertian_swir_3,	 path: LAMBERTIAN/LAMBERTIAN_B12.TIF
# insturement: satellite_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SATELLITE_AZIMUTH.TIF
# insturement: azimuthal_incident,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_AZIMUTHAL_INCIDENT.TIF
# insturement: nbar_coastal_aerosol,	 path: NBAR/NBAR_B01.TIF
# insturement: lambertian_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_LAMBERTIAN_CONTIGUITY.TIF
# insturement: lambertian_red_edge_1,	 path: LAMBERTIAN/LAMBERTIAN_B05.TIF
# insturement: lambertian_red_edge_2,	 path: LAMBERTIAN/LAMBERTIAN_B06.TIF
# insturement: lambertian_red_edge_3,	 path: LAMBERTIAN/LAMBERTIAN_B07.TIF
# insturement: nbart_coastal_aerosol,	 path: NBART/NBART_B01.TIF
# insturement: lambertian_coastal_aerosol,	 path: LAMBERTIAN/LAMBERTIAN_B01.TIF
# location of meta-data
# c1cd1733-f02f-4cff-a54d-376fb3844bfc
# ['s3://dea-public-data/L2/sentinel-2-nrt/S2MSIARD/2018-09-27/S2A_OPER_MSI_ARD_TL_EPAE_20180927T030744_A017044_T55GDN_N02.06/ARD-METADATA.yaml']
# ---------------------
# insturement: fmask,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_FMASK.TIF
# insturement: exiting,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_EXITING.TIF
# insturement: incident,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_INCIDENT.TIF
# insturement: nbar_red,	 path: NBAR/NBAR_B04.TIF
# insturement: nbar_blue,	 path: NBAR/NBAR_B02.TIF
# insturement: nbart_red,	 path: NBART/NBART_B04.TIF
# insturement: timedelta,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_TIMEDELTA.TIF
# insturement: nbar_green,	 path: NBAR/NBAR_B03.TIF
# insturement: nbar_nir_1,	 path: NBAR/NBAR_B08.TIF
# insturement: nbar_nir_2,	 path: NBAR/NBAR_B8A.TIF
# insturement: nbart_blue,	 path: NBART/NBART_B02.TIF
# insturement: nbar_swir_2,	 path: NBAR/NBAR_B11.TIF
# insturement: nbar_swir_3,	 path: NBAR/NBAR_B12.TIF
# insturement: nbart_green,	 path: NBART/NBART_B03.TIF
# insturement: nbart_nir_1,	 path: NBART/NBART_B08.TIF
# insturement: nbart_nir_2,	 path: NBART/NBART_B8A.TIF
# insturement: nbart_swir_2,	 path: NBART/NBART_B11.TIF
# insturement: nbart_swir_3,	 path: NBART/NBART_B12.TIF
# insturement: solar_zenith,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SOLAR_ZENITH.TIF
# insturement: solar_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SOLAR_AZIMUTH.TIF
# insturement: lambertian_red,	 path: LAMBERTIAN/LAMBERTIAN_B04.TIF
# insturement: relative_slope,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_RELATIVE_SLOPE.TIF
# insturement: satellite_view,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SATELLITE_VIEW.TIF
# insturement: terrain_shadow,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_COMBINED_TERRAIN_SHADOW.TIF
# insturement: lambertian_blue,	 path: LAMBERTIAN/LAMBERTIAN_B02.TIF
# insturement: nbar_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_NBAR_CONTIGUITY.TIF
# insturement: nbar_red_edge_1,	 path: NBAR/NBAR_B05.TIF
# insturement: nbar_red_edge_2,	 path: NBAR/NBAR_B06.TIF
# insturement: nbar_red_edge_3,	 path: NBAR/NBAR_B07.TIF
# insturement: lambertian_green,	 path: LAMBERTIAN/LAMBERTIAN_B03.TIF
# insturement: lambertian_nir_1,	 path: LAMBERTIAN/LAMBERTIAN_B08.TIF
# insturement: lambertian_nir_2,	 path: LAMBERTIAN/LAMBERTIAN_B8A.TIF
# insturement: nbart_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_NBART_CONTIGUITY.TIF
# insturement: nbart_red_edge_1,	 path: NBART/NBART_B05.TIF
# insturement: nbart_red_edge_2,	 path: NBART/NBART_B06.TIF
# insturement: nbart_red_edge_3,	 path: NBART/NBART_B07.TIF
# insturement: relative_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_RELATIVE_AZIMUTH.TIF
# insturement: azimuthal_exiting,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_AZIMUTHAL_EXITING.TIF
# insturement: lambertian_swir_2,	 path: LAMBERTIAN/LAMBERTIAN_B11.TIF
# insturement: lambertian_swir_3,	 path: LAMBERTIAN/LAMBERTIAN_B12.TIF
# insturement: satellite_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SATELLITE_AZIMUTH.TIF
# insturement: azimuthal_incident,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_AZIMUTHAL_INCIDENT.TIF
# insturement: nbar_coastal_aerosol,	 path: NBAR/NBAR_B01.TIF
# insturement: lambertian_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_LAMBERTIAN_CONTIGUITY.TIF
# insturement: lambertian_red_edge_1,	 path: LAMBERTIAN/LAMBERTIAN_B05.TIF
# insturement: lambertian_red_edge_2,	 path: LAMBERTIAN/LAMBERTIAN_B06.TIF
# insturement: lambertian_red_edge_3,	 path: LAMBERTIAN/LAMBERTIAN_B07.TIF
# insturement: nbart_coastal_aerosol,	 path: NBART/NBART_B01.TIF
# insturement: lambertian_coastal_aerosol,	 path: LAMBERTIAN/LAMBERTIAN_B01.TIF
# location of meta-data
# 9af91f68-6977-43f8-9d04-cd265ac54a81
# ['s3://dea-public-data/L2/sentinel-2-nrt/S2MSIARD/2018-09-07/S2A_OPER_MSI_ARD_TL_EPAE_20180907T012200_A016758_T55GDN_N02.06/ARD-METADATA.yaml']
# ---------------------
# insturement: fmask,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_FMASK.TIF
# insturement: exiting,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_EXITING.TIF
# insturement: incident,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_INCIDENT.TIF
# insturement: nbar_red,	 path: NBAR/NBAR_B04.TIF
# insturement: nbar_blue,	 path: NBAR/NBAR_B02.TIF
# insturement: nbart_red,	 path: NBART/NBART_B04.TIF
# insturement: timedelta,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_TIMEDELTA.TIF
# insturement: nbar_green,	 path: NBAR/NBAR_B03.TIF
# insturement: nbar_nir_1,	 path: NBAR/NBAR_B08.TIF
# insturement: nbar_nir_2,	 path: NBAR/NBAR_B8A.TIF
# insturement: nbart_blue,	 path: NBART/NBART_B02.TIF
# insturement: nbar_swir_2,	 path: NBAR/NBAR_B11.TIF
# insturement: nbar_swir_3,	 path: NBAR/NBAR_B12.TIF
# insturement: nbart_green,	 path: NBART/NBART_B03.TIF
# insturement: nbart_nir_1,	 path: NBART/NBART_B08.TIF
# insturement: nbart_nir_2,	 path: NBART/NBART_B8A.TIF
# insturement: nbart_swir_2,	 path: NBART/NBART_B11.TIF
# insturement: nbart_swir_3,	 path: NBART/NBART_B12.TIF
# insturement: solar_zenith,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SOLAR_ZENITH.TIF
# insturement: solar_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SOLAR_AZIMUTH.TIF
# insturement: lambertian_red,	 path: LAMBERTIAN/LAMBERTIAN_B04.TIF
# insturement: relative_slope,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_RELATIVE_SLOPE.TIF
# insturement: satellite_view,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SATELLITE_VIEW.TIF
# insturement: terrain_shadow,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_COMBINED_TERRAIN_SHADOW.TIF
# insturement: lambertian_blue,	 path: LAMBERTIAN/LAMBERTIAN_B02.TIF
# insturement: nbar_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_NBAR_CONTIGUITY.TIF
# insturement: nbar_red_edge_1,	 path: NBAR/NBAR_B05.TIF
# insturement: nbar_red_edge_2,	 path: NBAR/NBAR_B06.TIF
# insturement: nbar_red_edge_3,	 path: NBAR/NBAR_B07.TIF
# insturement: lambertian_green,	 path: LAMBERTIAN/LAMBERTIAN_B03.TIF
# insturement: lambertian_nir_1,	 path: LAMBERTIAN/LAMBERTIAN_B08.TIF
# insturement: lambertian_nir_2,	 path: LAMBERTIAN/LAMBERTIAN_B8A.TIF
# insturement: nbart_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_NBART_CONTIGUITY.TIF
# insturement: nbart_red_edge_1,	 path: NBART/NBART_B05.TIF
# insturement: nbart_red_edge_2,	 path: NBART/NBART_B06.TIF
# insturement: nbart_red_edge_3,	 path: NBART/NBART_B07.TIF
# insturement: relative_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_RELATIVE_AZIMUTH.TIF
# insturement: azimuthal_exiting,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_AZIMUTHAL_EXITING.TIF
# insturement: lambertian_swir_2,	 path: LAMBERTIAN/LAMBERTIAN_B11.TIF
# insturement: lambertian_swir_3,	 path: LAMBERTIAN/LAMBERTIAN_B12.TIF
# insturement: satellite_azimuth,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_SATELLITE_AZIMUTH.TIF
# insturement: azimuthal_incident,	 path: SUPPLEMENTARY/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_AZIMUTHAL_INCIDENT.TIF
# insturement: nbar_coastal_aerosol,	 path: NBAR/NBAR_B01.TIF
# insturement: lambertian_contiguity,	 path: QA/S2A_OPER_MSI_ARD_TL_EPAE_20180917T012034_A016901_T55GDN_N02.06_LAMBERTIAN_CONTIGUITY.TIF
# insturement: lambertian_red_edge_1,	 path: LAMBERTIAN/LAMBERTIAN_B05.TIF
# insturement: lambertian_red_edge_2,	 path: LAMBERTIAN/LAMBERTIAN_B06.TIF
# insturement: lambertian_red_edge_3,	 path: LAMBERTIAN/LAMBERTIAN_B07.TIF
# insturement: nbart_coastal_aerosol,	 path: NBART/NBART_B01.TIF
# insturement: lambertian_coastal_aerosol,	 path: LAMBERTIAN/LAMBERTIAN_B01.TIF
